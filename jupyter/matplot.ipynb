# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# %matplotlib inline

# %%
x = np.linspace(start=0, stop=5, num=11)
y = x**2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
 # plot()
plt.xlabel('X ROW')
plt.ylabel('Y COLUMN')
plt.title('Menu')
# Out:
# Text(0.5, 1.0, 'Menu')

# %%
plt.subplot(1,2,1)
plt.plot(x, y, 'r')

plt.subplot(1,2,2)
plt.plot(y, x, 'b')

# %%
fig = plt.figure()
axes = fig.add_axes([0.1, 0.1, 0.8, 0.8])

axes.plot(x,y,label='NO')
axes.plot(x*2,y*3,label= 'Yeah')
axes.set_xlabel('X ROW')
axes.set_ylabel('Y COL')
axes.set_title('Menu axes')
# Out:
# Text(0.5, 1.0, 'Menu axes')

# %%
fi = plt.figure()
axes2 = fi.add_axes([0.1, 0.1, 0.8, 0.8])
axes3 = fi.add_axes([0.2, 0.5, 0.4, 0.3])

# %%
a,b = plt.subplots(nrows=2, ncols=3)

# %%
fi_1 = plt.figure()
ax = fi_1.add_axes([0,0,1,1]) # show bang
# linestyle = ['-.', '--', ':', 'steps' ]

#  marker = <0, 1, '+', '*'>
# markersize = <int>
# markerfacecolor = <color>,
# markeredgewidth = <int>
# markeredgecolor = <color>

ax.plot(x,y,color='purple', lw=1, linestyle='--', marker='o', markersize=20,
        markerfacecolor='yellow', markeredgewidth=3, markeredgecolor='red'
       )
